# %%
# %load_ext autoreload
# %autoreload 2
from cieran import Cieran
import seaborn as sns
import numpy as np
sns.set_theme(style="white")
rs = np.random.RandomState(50)
import matplotlib.pyplot as plt

x, y = rs.normal(size=(2, 50))
def draw_kde(cmap):
    # Set up the matplotlib figure
    fig, ax = plt.subplots()
    sns.kdeplot(x=x, y=y, cmap=cmap, ax=ax, fill=True, clip=(-5, 5), cut=10, thresh=0, levels=9)
    # Adjust aspect ratio to be equal
    ax.set_aspect('equal')

    ax.set_axis_off()
    ax.set(xlim=(-3.5, 3.5), ylim=(-3.5, 3.5))
    plt.tight_layout()
    
    plt.show()

# %%
cie = Cieran(palette='tableau10', draw=draw_kde)
# Out:
# Output()

# %%
cie.teach()

# %%
cie.search()
# Out:
# IntProgress(value=0, layout=Layout(height='36px', margin='8px', width='auto'), max=20000)

# %%
cie.

# %%
cie.results(4)[0].ramp

# %%
draw_kde(cie.results(4)[3].ramp)

# %%
cie.results(4)[3].ramp

# %%
cie.results(4)[0].plot_all()

# %%
draw_figure(sns.cubehelix_palette(start=15, light=1, as_cmap=True))

# %%
import numpy as np
rs = np.random.RandomState(50)

# %%
# %load_ext autoreload
# %autoreload 2
