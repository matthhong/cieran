# %%
cie = Cieran(color='tableau10', draw=draw_hexbin)
# Out:
# Output()

# %%
cie.teach(); cie.search()
# Out:
# IntProgress(value=14, layout=Layout(height='36px', margin='8px', width='auto'), max=14, style=ProgressStyle(ba…
# IntProgress(value=0, layout=Layout(height='36px', margin='8px', width='auto'), max=20000, style=ProgressStyle(…

# %%
cie.options_display
# Out:
# GridBox(children=(Output(outputs=({'output_type': 'display_data', 'data': {'text/plain': "IntText(value=0, des…

# %%
len(cie._ranked_results.trajectories)
# Out:
# 147

# %%
draw_hexbin(cie._ranked_results[73].ramp)

# %%
draw_hexbin(cie._search_result.ramp)

# %%
cie2 = Cieran(color='tableau10', draw=draw_hexbin)
# Out:
# Output()

# %%
cie2.teach(); cie2.search()
# Out:
# IntProgress(value=14, layout=Layout(height='36px', margin='8px', width='auto'), max=14, style=ProgressStyle(ba…
# IntProgress(value=0, layout=Layout(height='36px', margin='8px', width='auto'), max=20000, style=ProgressStyle(…

# %%
cie2.options_display
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 cie2.options_display
#
# File ~/Projects/cieran/cieran/train.py:251, in Cieran.options_display(self, shuffle)
#     248 results = [self.search_result()] + self.ranked_results(1)
#     250 # Get the middle element of _ranked_results
# --> 251 middle = len(self._ranked_results) // 2
#     252 median = self._ranked_results[middle].ramp
#     254 # Get the last element of _ranked_results
#
# TypeError: object of type 'TrajectorySet' has no len()

# %%
cie._ranked_results[-1].ramp

# %%
cie2.save_data()

# %%
cie3 = Cieran(color='tableau10', draw=draw_hexbin)
# Out:
# Output()

# %%
cie3.teach(); cie3.search()
# Out:
# IntProgress(value=14, layout=Layout(height='36px', margin='8px', width='auto'), max=14, style=ProgressStyle(ba…
# IntProgress(value=0, layout=Layout(height='36px', margin='8px', width='auto'), max=20000, style=ProgressStyle(…

# %%
cie3.options_display
# Out:
# GridBox(children=(Output(outputs=({'output_type': 'display_data', 'data': {'text/plain': "IntText(value=0, des…

# %%
cie3.save_data()

# %%
cie.save_data()

# %%
draw_hexbin('Blues')

# %%
# %load_ext autoreload
# %autoreload 2
from cieran import Cieran
import seaborn as sns
import numpy as np
sns.set_theme(style="white")
rs = np.random.RandomState(10)
import matplotlib.pyplot as plt

x, y = rs.normal(size=(2, 500), scale=2)
def draw_kde(cmap):
    # Set up the matplotlib figure
    fig, ax = plt.subplots()
    
    cmap = plt.get_cmap(cmap)
    sns.kdeplot(x=x, y=y, cmap=cmap, ax=ax, fill=True)
    # Adjust aspect ratio to be equal
    ax.set_aspect('equal')

    ax.set_axis_off()
    ax.set(xlim=(-6, 6), ylim=(-6, 6))
    plt.tight_layout()
    
    plt.show()
    
def draw_heatmap(cmap):
    # Set up the matplotlib figure
    fig, ax = plt.subplots()
    
    cmap = plt.get_cmap(cmap)
    sns.histplot(x=x, y=y, cmap=cmap, ax=ax,  bins=20)
    # Adjust aspect ratio to be equal
    ax.set_aspect('equal')

    ax.set_axis_off()
    ax.set(xlim=(-6, 6), ylim=(-6, 6))
    plt.tight_layout()

    plt.show()

def draw_hexbin(cmap):
    # Set up the matplotlib figure
    # fig, ax = plt.subplots()
    
    fig, ax = plt.subplots()
    cmap = plt.get_cmap(cmap)
    plt.hexbin(x, y, cmap=cmap, gridsize=20)

    ax.set_aspect('equal')

    ax.set_axis_off()
    ax.set(xlim=(-6, 6), ylim=(-6, 6))
    plt.tight_layout()

    plt.show()
    
def draw_scatter(cmap):
    # Set up the matplotlib figure
    # fig, ax = plt.subplots()
    
    fig, ax = plt.subplots()
    cmap = plt.get_cmap(cmap).reversed()
    plt.scatter(x, y, c='black')

    ax.set_aspect('equal')

    ax.set_axis_off()
    ax.set(xlim=(-6, 6), ylim=(-6, 6))
    plt.tight_layout()

    plt.show()
