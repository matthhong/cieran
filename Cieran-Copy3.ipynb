# %%
cie = Cieran(color='tableau10', draw=draw_kde)
# Out:
# Output()

# %%
cie._env.set_reward_weights([-0.32714125 ,0.25778596 ,0.68010007,-0.21371967, 0.47065449, 0.16493434,
 -0.1781463,   0.19420679, -0.01189283])

# %%
cie._ranker()

# %%
cie.search()
# Out:
# IntProgress(value=0, layout=Layout(height='36px', margin='8px', width='auto'), max=20000, style=ProgressStyle(…

# %%
cie.teach(); cie.search()
# Out:
# IntProgress(value=14, layout=Layout(height='36px', margin='8px', width='auto'), max=14, style=ProgressStyle(ba…
# IntProgress(value=0, layout=Layout(height='36px', margin='8px', width='auto'), max=20000, style=ProgressStyle(…

# %%
cie.options_display
# Out:
# GridBox(children=(Output(outputs=({'output_type': 'display_data', 'data': {'text/plain': "IntText(value=0, des…

# %%
cie.options(25)
# Out:
# GridBox(children=(Output(outputs=({'output_type': 'display_data', 'data': {'text/plain': "IntText(value=0, des…

# %%
cie.data
# Out:
# {'id': 6227,
#  'choice': {},
#  'choice2': {0: 1, 1: 2, 2: 3, 3: 4},
#  'color': '#bb8bb0',
#  'block': 1,
#  'trajectories2': [[(100, 0, 0),
#    (75.11414164101843, -0.7057349005499987, 5.239273083280324),
#    (67.22324715645988, -0.7463674786635579, -0.048842623693673204),
#    (65.11527221896569, 27.01168885400716, -9.094152476696507),
#    (49.40415812620482, 30.935598229549697, -7.0424395152736),
#    (40.97151302477667, 34.78609994098204, -5.5411731280691185),
#    (35.45289713047779, 48.981574426407235, -11.08499064662341),
#    (0, 0, 0)],
#   [array([100,   0,   0]),
#    array([ 84.68380574, -27.62851463,  40.99296224]),
#    array([ 80.21880101, -17.94915963,  36.9463678 ]),
#    array([ 78.52249332, -11.70078392,  20.7693515 ]),
#    array([75.11414164, -0.7057349 ,  5.23927308]),
#    array([66.73965732, 15.61914436,  2.43907689]),
#    array([65.11527222, 27.01168885, -9.09415248]),
#    array([0, 0, 0])],
#   [array([100,   0,   0]),
# ...

# %%
cie._env.set_reward_weights([-0.32714125 ,0.25778596 ,0.68010007,-0.21371967, 0.47065449, 0.16493434,
 -0.1781463,   0.19420679, -0.01189283])

# %%
cie.save_data()

# %%
cie2 = Cieran(color='tableau10', draw=draw_kde)
# Out:
# Output()

# %%
cie2.teach(); cie2.search()
# Out:
# IntProgress(value=14, layout=Layout(height='36px', margin='8px', width='auto'), max=14, style=ProgressStyle(ba…
# IntProgress(value=0, layout=Layout(height='36px', margin='8px', width='auto'), max=20000, style=ProgressStyle(…

# %%
cie2.options_display
# Out:
# GridBox(children=(Output(outputs=({'output_type': 'display_data', 'data': {'text/plain': "IntText(value=0, des…

# %%
cie2.save_data()

# %%
cie3 = Cieran(color='tableau10', draw=draw_kde)
# Out:
# Output()

# %%
cie3.teach(); cie3.search()
# Out:
# IntProgress(value=14, layout=Layout(height='36px', margin='8px', width='auto'), max=14, style=ProgressStyle(ba…
# IntProgress(value=0, layout=Layout(height='36px', margin='8px', width='auto'), max=20000, style=ProgressStyle(…

# %%
cie3.options_display
# Out:
# GridBox(children=(Output(outputs=({'output_type': 'display_data', 'data': {'text/plain': "IntText(value=0, des…

# %%
cie3.save_data()

# %%
cie2 = Cieran(color='tableau10', draw=draw_kde)
# Out:
# Output()

# %%
cie2._env.set_reward_weights([-0.87360337, 0.33531586,  0.05415825, -0.02326773,  0.12038894,  0.04660696,
 -0.14320017, -0.20713601,  0.20206086])

# %%
cie2._ranker(); cie2.search()
# Out:
# IntProgress(value=0, layout=Layout(height='36px', margin='8px', width='auto'), max=20000, style=ProgressStyle(…

# %%
cie2.options(46)
# Out:
# GridBox(children=(Output(outputs=({'output_type': 'display_data', 'data': {'text/plain': "IntText(value=0, des…

# %%
draw_hexbin(cmap=cie3.search_result())

# %%
def draw_heatmap(cmap):
    # Set up the matplotlib figure
    fig, ax = plt.subplots()
    
    cmap = plt.get_cmap(cmap)
    
    sns.histplot(x=x, y=y, cmap=cmap, ax=ax,  bins=20)
    # Adjust aspect ratio to be equal
    ax.set_aspect('equal')

    ax.set_axis_off()
    ax.set(xlim=(-6, 6), ylim=(-6, 6))
    plt.tight_layout()

    plt.show()

# %%
draw_heatmap('viridis')

# %%
cie = Cieran(color='tableau10', draw=draw_heatmap)
# Out:
# Output()

# %%
cie.teach(); cie.search()
# Out:
# IntProgress(value=14, layout=Layout(height='36px', margin='8px', width='auto'), max=14, style=ProgressStyle(ba…
# IntProgress(value=0, layout=Layout(height='36px', margin='8px', width='auto'), max=20000, style=ProgressStyle(…

# %%
cie.options_display
# Out:
# GridBox(children=(Output(outputs=({'output_type': 'display_data', 'data': {'text/plain': "IntText(value=0, des…

# %%
from numpy import array
khairi=[array([100,   0,   0]), array([95.4164401 , -5.66155945, -0.55528574]), array([ 86.5033243 ,   4.27877936, -13.18736264]), array([81.47556031, 12.05584168, -1.22185421]), array([73.66856851, 10.00896082, -8.22569993]), array([65.11527222, 27.01168885, -9.09415248]), array([ 54.46770386,  34.27225447, -16.2455712 ]), array([ 47.4565084 ,  29.28877336, -18.34845015]), array([ 46.55263414,  48.0945921 , -14.57007577]), array([ 37.25414408,  55.30370417, -26.6523367 ]), array([0, 0, 0])]

# %%
[[(100, 0, 0), (86.5033242995572, 4.278779363946626, -13.187362635701177), (81.47556031465275, 12.055841680407582, -1.2218542052598451), (65.11527221896569, 27.01168885400716, -9.094152476696507), (47.45650840298987, 29.28877336027503, -18.348450145905687), (46.5526341395092, 48.094592101718945, -14.57007576649842), (43.08565934813569, 55.36942724702794, -17.608409360170697), (37.25414408454593, 55.303704170984986, -26.65233669860031), (0, 0, 0)], [array([100,   0,   0]), array([95.4164401 , -5.66155945, -0.55528574]), array([ 86.5033243 ,   4.27877936, -13.18736264]), array([81.47556031, 12.05584168, -1.22185421]), array([73.66856851, 10.00896082, -8.22569993]), array([65.11527222, 27.01168885, -9.09415248]), array([ 54.46770386,  34.27225447, -16.2455712 ]), array([ 47.4565084 ,  29.28877336, -18.34845015]), array([ 46.55263414,  48.0945921 , -14.57007577]), array([ 37.25414408,  55.30370417, -26.6523367 ]), array([0, 0, 0])], [array([100,   0,   0]), array([81.82112322, 20.82152182,  9.97087504]), array([81.47556031, 12.05584168, -1.22185421]), array([73.66856851, 10.00896082, -8.22569993]), array([65.11527222, 27.01168885, -9.09415248]), array([ 47.4565084 ,  29.28877336, -18.34845015]), array([ 40.2502224 ,  38.05725113, -23.94571397]), array([ 31.17578311,  46.04964637, -20.31874845]), array([ 22.68414526,  39.64323761, -19.08887407]), array([0, 0, 0])], [array([100,   0,   0]), array([95.4164401 , -5.66155945, -0.55528574]), array([81.47556031, 12.05584168, -1.22185421]), array([73.66856851, 10.00896082, -8.22569993]), array([65.11527222, 27.01168885, -9.09415248]), array([ 54.46770386,  34.27225447, -16.2455712 ]), array([ 46.55263414,  48.0945921 , -14.57007577]), array([ 35.45289713,  48.98157443, -11.08499065]), array([0, 0, 0])]]","[1.389061574430354, 1.3669639523983526, 1.3656864561469177, 1.364046027441531]"

# %%
from cieran import Trajectory, Environment

# %%
kmap = Trajectory(None, khairi)

# %%
draw_heatmap(kmap.ramp)

# %%
cie2 = Cieran(color='tableau10', draw=draw_heatmap)
# Out:
# Output()

# %%
cie2.teach(); cie2.search()
# Out:
# IntProgress(value=14, layout=Layout(height='36px', margin='8px', width='auto'), max=14, style=ProgressStyle(ba…
# IntProgress(value=0, layout=Layout(height='36px', margin='8px', width='auto'), max=20000, style=ProgressStyle(…

# %%
cie2.options_display
# Out:
# GridBox(children=(Output(outputs=({'output_type': 'display_data', 'data': {'text/plain': "IntText(value=0, des…

# %%
cie2._ranked_results[0].plot_all()

# %%
cie2._ranked_results[1].plot_all()

# %%
cie2._ranked_results[2].plot_all()

# %%
cie2.data
# Out:
# {'id': 6963,
#  'choice': {1: 1, 3: 3, 0: 2, 2: 4},
#  'color': '#f88253',
#  'block': 1,
#  'weights': array([-0.87360337,  0.33531586,  0.05415825, -0.02326773,  0.12038894,
#          0.04660696, -0.14320017, -0.20713601,  0.20206086]),
#  'trajectories': [[(100, 0, 0),
#    (95.41644009897952, -5.661559453968096, -0.5552857361335555),
#    (90.01912438180403, 2.930395845661195, 18.557029672040585),
#    (84.98442455114173, 15.655942156028715, 23.977908056342756),
#    (79.91334701127954, 24.676523991668034, 28.927894889650815),
#    (67.62283795167193, 28.798757742384566, 38.57480670657523),
#    (64.37780047449037, 44.6137529321274, 52.89582958083213),
#    (60.17154466843016, 58.47595901049834, 53.58941322355403),
#    (53.587523135658174, 68.90962520868393, 59.238196472858846),
#    (48.35360940300204, 63.442658454636046, 55.73218427460546),
#    (39.573674246075335, 55.326948609668136, 38.92948215399741),
#    (28.012917453201673, 49.89657696642496, 23.33405929291942),
# ...

# %%
cie4 = Cieran(color='tableau10', draw=draw_heatmap)
# Out:
# Output()

# %%
cie2.teach(6); cie2.search()
# Out:
# IntProgress(value=5, layout=Layout(height='36px', margin='8px', width='auto'), max=5, style=ProgressStyle(bar_…
# IntProgress(value=0, layout=Layout(height='36px', margin='8px', width='auto'), max=20000, style=ProgressStyle(…

# %%
cie2.options_display
# Out:
# GridBox(children=(Output(outputs=({'output_type': 'display_data', 'data': {'text/plain': "IntText(value=0, des…

# %%
cie2._ranked_results[0].plot_all()

# %%
khairi = Cieran(color='tableau10', draw=draw_heatmap)
# Out:
# Output()

# %%
khairi._env.set_reward_weights([-0.32714125,0.25778596,  0.68010007, -0.21371967,  0.47065449,  0.16493434,
 -0.1781463,   0.19420679, -0.01189283])

# %%
khairi.search()
# Out:
# IntProgress(value=0, layout=Layout(height='36px', margin='8px', width='auto'), max=20000, style=ProgressStyle(…

# %%
khairi._ranker()

# %%
khairi.options_display
# Out:
# GridBox(children=(Output(outputs=({'output_type': 'display_data', 'data': {'text/plain': "IntText(value=0, des…

# %%
khairi._belief_model.reward(khairi._ranked_results[1])
# Out:
# -0.30650095337647004

# %%
khairi._ranked_results[1].ramp
# Out:
# True

# %%
cie2.save_data()

# %%
cie3 = Cieran(color='tableau10', draw=draw_heatmap)
# Out:
# Output()

# %%
cie3.teach(); cie3.search()
# Out:
# IntProgress(value=14, layout=Layout(height='36px', margin='8px', width='auto'), max=14, style=ProgressStyle(ba…
# IntProgress(value=0, layout=Layout(height='36px', margin='8px', width='auto'), max=20000, style=ProgressStyle(…

# %%
cie3.options_display
# Out:
# GridBox(children=(Output(outputs=({'output_type': 'display_data', 'data': {'text/plain': "IntText(value=0, des…

# %%
cie3.save_data()

# %%
cie.save_data()

# %%
cie.data
# Out:
# {'id': 3351,
#  'choice': {3: 1, 1: 2, 0: 3, 2: 4},
#  'color': '#447ba0',
#  'block': 1,
#  'weights': array([ 0.00077064,  0.39561509,  0.57947449,  0.37104815, -0.04745118,
#         -0.43925534,  0.14468509, -0.1988866 ,  0.33813335]),
#  'trajectories': [[(100, 0, 0),
#    (52.71571890389497, -7.538604313254581, -27.351846035858088),
#    (41.619535209881484, 0.22127702269216343, -31.606544044837108),
#    (31.466742637575727, 16.172632363439845, -34.20767964289983),
#    (21.056650090974983, 33.45112218380012, -43.42364785430894),
#    (0, 0, 0)],
#   [array([100,   0,   0]),
#    array([ 84.65488682, -13.68933746, -12.74316011]),
#    array([ 65.39880683, -10.92973249, -18.59120737]),
#    array([ 52.7157189 ,  -7.53860431, -27.35184604]),
#    array([ 41.61953521,   0.22127702, -31.60654404]),
#    array([ 31.46674264,  16.17263236, -34.20767964]),
#    array([ 21.05665009,  33.45112218, -43.42364785]),
#    array([ 15.00104574,  28.24849987, -35.64121823]),
# ...

# %%
cie.data
# Out:
# {'id': 5904, 'choice': {}, 'color': '#e15956', 'block': 1}

# %%
cie.save_data()

# %%
cie._search_result.ramp

# %%
cie._search_result.plot_all()

# %%
cie._ranked_results[0].plot_all()

# %%
cie._ranked_results[1].plot_all()

# %%
cie._ranked_results[2].plot_all()

# %%
len(cie.candidates) == len(list(set(cie.candidates)))
# Out:
# True

# %%
len(list(set(cie.candidates)))
# Out:
# 95

# %%
len(cie.candidates)
# Out:
# 95

# %%
cie._env.set_reward_weights([-0.3598897 , -0.07824826,  0.01423649,  0.87368521,  0.15416821,
       -0.18356091,  0.08570207,  0.09642398, -0.16347237])
cie._ranker()

# %%
cie._search_result.ramp

# %%
cie._search_result.plot_all()

# %%
cie.data
# Out:
# {'id': 3128,
#  'choice': {1: 1, 2: 2, 0: 3, 3: 4},
#  'color': '#5fa145',
#  'block': 5,
#  'weights': array([ 0.37785071, -0.34765632, -0.41746204, -0.4554302 , -0.45749552,
#          0.11195241, -0.34550528,  0.03635855,  0.11018791]),
#  'trajectories': [[(100, 0, 0),
#    (90.35565968105638, -51.82511610695619, 27.301635630979746),
#    (85.01691213217556, -46.84712948315372, 17.786342259078765),
#    (84.89715057872216, -40.79231547787339, 5.485707032513119),
#    (84.54961078077137, -47.48633699784705, -13.222387410607709),
#    (80.6578636276149, -29.886793639834806, -21.479689439428157),
#    (68.54582306997928, -25.320943448720783, -28.64253651837744),
#    (57.67597540373936, -19.39054639310109, -28.22712372692098),
#    (52.71571890389497, -7.538604313254581, -27.351846035858088),
#    (39.190779247186846, -6.926690363536409, -11.966940856256201),
#    (34.85528340837616, 3.738357262947602, 6.03165037875317),
# ...

# %%
cie._belief_model.reward(cie._ranked_results[1])
# Out:
# 1.5786152903467796

# %%
np.dot(cie._ranked_results[2].features, cie._env.reward_weights)
# Out:
# 1.5776199670304027

# %%
np.dot(cie._ranked_results[1].features, cie._env.reward_weights)
# Out:
# 1.5786152903467796

# %%
cie._ranked_results[2].plot_all()

# %%
cie._ranked_results[1].plot_all()

# %%
cie._ranked_results[2].plot_all()

# %%
draw_hexbin(cie._search_result.ramp)

# %%
draw_kde(cie._search_result.ramp)

# %%
import matplotlib.pyplot as plt
plt.plot(cie.reward_history)

# %%
cie._env.total_reward
# Out:
# 0

# %%
import numpy as np
np.dot(cie._ranked_results[1].features, cie._env.reward_weights)
# Out:
# 0.948404479672259

# %%
cie._ranked_results[0].ramp

# %%
cie._search_result.ramp

# %%
len(cie._ranked_results.trajectories)
# Out:
# 115

# %%
len(cie._trajectories.trajectories)
# Out:
# 115

# %%
cie._user_model.params
# Out:
# {'weights': array([ 0.37264288,  0.02619547,  0.16694996,  0.52700641,  0.53535504,
#          0.04684321, -0.38594656,  0.32413764, -0.10965294]),
#  'beta': 1.0,
#  'beta_D': 1.0,
#  'delta': 0.1}

# %%
cie._user_model.params
# Out:
# {'weights': array([ 0.37264288,  0.02619547,  0.16694996,  0.52700641,  0.53535504,
#          0.04684321, -0.38594656,  0.32413764, -0.10965294]),
#  'beta': 1.0,
#  'beta_D': 1.0,
#  'delta': 0.1}

# %%
cie._search_result.features
# Out:
# array([0.37124647, 0.67870935, 0.86981041, 1.00174231, 1.00174231,
#        1.00174231, 1.00174231, 0.75179939, 0.62261322])

# %%
cie._env.reward_weights
# Out:
# array([ 0.58321339,  0.27748829,  0.01145436, -0.00898663,  0.58144736,
#         0.18668205,  0.07861324, -0.30407297,  0.33328487])

# %%
cie._env.feature_func(cie._search_result)
# Out:
# array([0.37124647, 0.67870935, 0.86981041, 1.00174231, 1.00174231,
#        1.00174231, 1.00174231, 0.75179939, 0.62261322])

# %%
cie._search_result.plot_all()

# %%
cie._user_model.reward(cie._search_result)
# Out:
# -0.246650817167108

# %%
np.sort(cie._user_model.reward(cie._trajectories))[::-1]
# Out:
# array([ 0.02846896, -0.00874429, -0.00983332, -0.05567948, -0.06136676,
#        -0.064542  , -0.06458474, -0.06605377, -0.07742899, -0.07742899,
#        -0.07911735, -0.08215396, -0.08224271, -0.08224271, -0.08879141,
#        -0.09088448, -0.09232331, -0.09287699, -0.09433399, -0.09558888,
#        -0.09650976, -0.09796451, -0.09894553, -0.09965719, -0.10088155,
#        -0.1023233 , -0.10370735, -0.10529026, -0.10694572, -0.10694572,
#        -0.10751462, -0.10768828, -0.11214333, -0.11455166, -0.11492003,
#        -0.11724486, -0.11724486, -0.11844948, -0.12787427, -0.12970654,
#        -0.13290498, -0.13290498, -0.13349625, -0.13349625, -0.13349625,
#        -0.1355131 , -0.1364974 , -0.13706465, -0.1373892 , -0.13809862,
#        -0.13809862, -0.13809862, -0.13927224, -0.14051954, -0.14225556,
#        -0.14350505, -0.14536115, -0.14758914, -0.14913351, -0.14993682,
#        -0.15360587, -0.15562714, -0.15583747, -0.15734426, -0.15954417,
# ...

# %%
cie._user_model.reward(cie._trajectories)
# Out:
# array([-0.20438964, -0.08224271, -0.15954417, -0.17089591, -0.16748433,
#        -0.2126533 , -0.13349625, -0.13809862, -0.10694572, -0.13290498,
#        -0.22492226, -0.07742899, -0.17707599, -0.17707599, -0.00874429,
#        -0.08215396, -0.08879141, -0.12970654, -0.19996677, -0.09558888,
#        -0.17888885, -0.19312083, -0.19312083, -0.16636589, -0.21501492,
#        -0.18525191, -0.24253595, -0.14536115, -0.13809862, -0.13349625,
#        -0.30730905, -0.06136676, -0.27204191, -0.13927224, -0.09894553,
#        -0.07911735, -0.11492003, -0.15583747, -0.00983332, -0.20441178,
#        -0.2052615 , -0.20167782, -0.20978215, -0.09650976, -0.16028841,
#        -0.16430927, -0.1373892 , -0.10751462, -0.16248848, -0.24024184,
#        -0.11724486, -0.10529026, -0.06605377, -0.09088448, -0.21445842,
#        -0.24715782, -0.24715782, -0.09433399, -0.24271871, -0.11214333,
#        -0.14758914, -0.20539954, -0.13706465, -0.22509627, -0.06458474,
# ...

# %%
np.dot(cie._trajectories.trajectories[ranked[0]].features, cie._env.reward_weights)
# Out:
# 0.9777577644061503

# %%
cie._trajectories[0]

# %%
ranked = np.argsort(cie._belief_model.reward(cie._trajectories))[::-1]
results = []

for i in ranked:
    results.append(cie._trajectories[i])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       2 results = []
#       4 for i in ranked:
# ----> 5     results.append(cie._trajectories[i])
#
# File ~/Projects/cieran/cieran/basics/trajectory.py:266, in TrajectorySet.__getitem__(self, idx)
#     264 def __getitem__(self, idx: Union[int, List[int], np.array]):
#     265     if isinstance(idx, list) or type(idx).__module__ == np.__name__:
# --> 266         return TrajectorySet([self.trajectories[i] for i in idx])
#     267     return self.trajectories[idx]
#
# TypeError: 'numpy.int64' object is not iterable

# %%
cie._trajectories[0]

# %%
cie._trajectories.trajectories[0]

# %%
# %load_ext autoreload
# %autoreload 2
from cieran import Cieran
import seaborn as sns
import numpy as np
sns.set_theme(style="white")
rs = np.random.RandomState(10)
import matplotlib.pyplot as plt

x, y = rs.normal(size=(2, 500), scale=2)
def draw_kde(cmap):
    # Set up the matplotlib figure
    fig, ax = plt.subplots()
    
    cmap = plt.get_cmap(cmap)
    sns.kdeplot(x=x, y=y, cmap=cmap, ax=ax, fill=True)
    # Adjust aspect ratio to be equal
    ax.set_aspect('equal')

    ax.set_axis_off()
    ax.set(xlim=(-6, 6), ylim=(-6, 6))
    plt.tight_layout()
    
    plt.show()
    
def draw_heatmap(cmap):
    # Set up the matplotlib figure
    fig, ax = plt.subplots()
    
    cmap = plt.get_cmap(cmap)
    sns.histplot(x=x, y=y, cmap=cmap, ax=ax,  bins=20)
    # Adjust aspect ratio to be equal
    ax.set_aspect('equal')

    ax.set_axis_off()
    ax.set(xlim=(-6, 6), ylim=(-6, 6))
    plt.tight_layout()

    plt.show()

def draw_hexbin(cmap):
    # Set up the matplotlib figure
    # fig, ax = plt.subplots()
    
    fig, ax = plt.subplots()
    cmap = plt.get_cmap(cmap)
    plt.hexbin(x, y, cmap=cmap, gridsize=20)

    ax.set_aspect('equal')

    ax.set_axis_off()
    ax.set(xlim=(-6, 6), ylim=(-6, 6))
    plt.tight_layout()

    plt.show()
    
def draw_scatter(cmap):
    # Set up the matplotlib figure
    # fig, ax = plt.subplots()
    
    fig, ax = plt.subplots()
    cmap = plt.get_cmap(cmap).reversed()
    plt.scatter(x, y, c='black')

    ax.set_aspect('equal')

    ax.set_axis_off()
    ax.set(xlim=(-6, 6), ylim=(-6, 6))
    plt.tight_layout()

    plt.show()

# %%
draw_scatter('gray')

# %%
draw_heatmap('gray')

# %%
draw_heatmap(cie._search_result.ramp)

# %%
draw_heatmap('cubehelix')

# %%
draw_kde(cie._search_result.ramp)

# %%
cie._search_result.ramp.resampled(11)
